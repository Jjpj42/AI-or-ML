# %%
import networkx as nx
import matplotlib.pyplot as plt
from tkinter import *
from PIL import Image, ImageTk


g = nx.Graph()

g.add_node(1, pos=(6,18))
g.add_node(2, pos=(4,17))
g.add_node(3, pos=(1.5,14.5))
g.add_node(4, pos=(6,15))
g.add_node(5, pos=(4,13))
g.add_node(6, pos=(-2,12))
g.add_node(7, pos=(-9,12))
g.add_node(8, pos=(-9,7))
g.add_node(9, pos=(0,7))
g.add_node(10, pos=(2,9))
g.add_node(11, pos=(2,2))
g.add_node(12, pos=(-2,3))
g.add_node(13, pos=(-9,2))
g.add_node(14, pos=(-2,-4))
g.add_node(15, pos=(0,-7))
g.add_node(16, pos=(3,-3))
g.add_node(17, pos=(5,-7))
g.add_node(18, pos=(6,8))
g.add_node(19, pos=(8.5,8.5))
g.add_node(20, pos=(10,11))
g.add_node(21, pos=(11,7))
g.add_node(22, pos=(12.5,2))
g.add_node(23, pos=(13,-2))
g.add_node(24, pos=(11,-6))
g.add_node(25, pos=(8,-3))

g.add_edge(1,2,weight=0.79)
g.add_edge(1,4,weight=1.9)
g.add_edge(2,3,weight=4.9)
g.add_edge(2,4,weight=17.4)
g.add_edge(3,5,weight=20.2)
g.add_edge(4,5,weight=2.5)
g.add_edge(3,6,weight=19)
g.add_edge(5,10,weight=22.7)
g.add_edge(6,7,weight=89.9)
g.add_edge(6,9,weight=15.2)
g.add_edge(9,10,weight=1.3)
g.add_edge(7,8,weight=29.4)
g.add_edge(8,13,weight=29.6)
g.add_edge(9,12,weight=7.6)
g.add_edge(12,14,weight=14.5)
g.add_edge(4,19,weight=85.4)
g.add_edge(10,18,weight=51.1)
g.add_edge(10,11,weight=31.1)
g.add_edge(11,16,weight=35.9)
g.add_edge(12,8,weight=38.5)
g.add_edge(13,14,weight=54.4)
g.add_edge(14,15,weight=10.1)
g.add_edge(15,16,weight=17.5)
g.add_edge(15,17,weight=18.3)
g.add_edge(17,18,weight=23.1)
g.add_edge(18,19,weight=9.6)
g.add_edge(19,20,weight=0.6)
g.add_edge(20,21,weight=3.3)
g.add_edge(21,22,weight=11)
g.add_edge(22,23,weight=4.3)
g.add_edge(23,24,weight=8.4)
g.add_edge(24,25,weight=12.9)
g.add_edge(17,25,weight=20.6)
g.add_edge(21,25,weight=16)

pos =nx.get_node_attributes(g,'pos')
labels = nx.get_edge_attributes(g,'weight')

nx.draw_networkx_edge_labels(g,pos,edge_labels=labels)
nx.draw(g, pos, with_labels=True,font_color='red',node_size= 1000)

again ='y' 

while again =='y':
    print("-"*50)
    print("|"+"MENU".center(48)+"|")
    print("-"*50)
    print("| 1.หาเส้นทางสั้นสุดจาก A -> B".ljust(53)+"|")    
    print("| 2.กำหนดได้ว่า ไปเที่ยว 2-5 ที่ แนะนำเส้นทางที่สั้นสุด".ljust(61)+"|""\n|  สำหรับเดินทางเที่ยว 5 ที่ คือเส้นทางไหน".ljust(59)+"|")
    print("| 3.คิดค่าแท็กซี่".ljust(54)+"|") 
    print("| 4.ออกจากเมนู".ljust(50)+"|")
    print("-"*50)
    n = input("โปรดเลือกเมนู: ")
    if n == "1":
        print("-"*50)
        print("|"+"location".center(48)+"|")
        print("-"*50)
        print("| 1. ดอยอินทนนท์".ljust(25)+"|", "2. อ่างกา".ljust(25)+"|")
        print("| 3. 2 มหาเจดีย์ ".ljust(25)+"|", "4. น้ำตกสิริภูมิ".ljust(29)+"|")
        print("| 5. ตลาดม้ง ".ljust(24)+"|", "6. น้ำตกสิริธาร".ljust(27)+"|")
        print("| 7. สวนสนบ่อแก้ว".ljust(25)+"|", "8. พัทยาเมืองฮอด".ljust(26)+"|")
        print("| 9. น้ำตกแม่กลาง".ljust(25)+"|", "10. ถ้ำบริจินดา".ljust(27)+"|")
        print("| 11. ผาช่อ แกรนด์แคนยอน".ljust(25)+"|", "12. โคบาลฮัท".ljust(25)+"|")
        print("| 13. ทะเลสาบดอยเต่า ".ljust(24)+"|", "14. วัดพระธาตุจอมทอง".ljust(26)+"|")
        print("| 15. วัดพระธาตุดอยน้อย ".ljust(26)+"|", "16. พิพิธภันฑ์พระพิฆเนศ".ljust(29)+"|")
        print("| 17. เวียงท่ากาน".ljust(25)+"|", "18. แกรนด์แคนยอน".ljust(25)+"|")
        print("| 19. ไนท์ซาฟารี".ljust(25)+"|", "20. อุทยานหลวงราชพฤกษ์".ljust(26)+"|")
        print("| 21. วัดพระธาตุดอยคำ".ljust(25)+"|", "22. พิพิธภัณฑ์โบราณ".ljust(28)+"|")
        print("| 23. เมืองเชียงใหม่ ".ljust(26)+"|", "24. กุมกาม".ljust(25)+"|")
        print("| 25. หมู่บ้านหัตกรรมถวาย".ljust(27)+"|", "".ljust(24)+"|")
        print("-"*50)
        
        img = Image.open("chiangmai.png")
        img.show()
    if n == "2":

          lc = (input('เลือกไปเที่ยวกี่ที่: ')) 

          if lc == "2":
                      lc1 = int(input('จุดที่ 1 :  '))
                      lc2 = int(input('จุดที่ 2 :  '))                
                      print('เส้นทางที่สั้นที่สุด : ',
                      nx.shortest_path(g, source=lc1, target=lc2))
                      print('ระยะที่สั้นที่สุด : ',
                      nx.shortest_path_length(g, source=lc1, target=lc2, weight='weight'),'km.')
                      plt.show()
                      
          if lc =="3":
                    min =0
                    max =0
                    mid = 0
                    arr =[]
                    newarr =[]                  
                   
                  
                    lc1 = int(input('จุดที่ 1 : '))
                    lc2 = int(input('จุดที่ 2 : '))
                    lc3 = int(input('จุดที่ 3 : '))
                    arr=[lc1,lc2,lc3]
                    newarr=sorted(arr)
                    if (lc1<lc2 and lc2<lc3 and lc1 < lc3) : 
                      min = lc1
                      max = lc3
                      mid = lc2
                    elif (lc3<lc2 and lc1 < lc2 and lc3 <  lc1)  :
                      min= lc3
                      max = lc2
                      mid = lc1 
                    elif(lc3 <lc1 and lc2<lc1 and lc2 < lc3) :
                      min=lc2
                      max= lc1
                      mid = lc3

                  
                    print('เส้นทางที่สั้นที่สุด : ',  
                    #newarr)            #ไม่มีทางผ่าน   
                    nx.shortest_path(g, source=newarr[0], target= newarr[1] and newarr[2])) #มีทางผ่าน 
                    print('ระยะที่สั้นที่สุด : ',
                    nx.shortest_path_length(g, source=min, target=max, weight='weight'),'km.')
                    plt.show()
                    
          if lc =="4":
                    min =0
                    max =0
                    mid = 0
                    mid1 =0
                    arr=[]
                    newarr =[]
                    lc1 = int(input('จุดที่ 1 : '))
                    lc2 = int(input('จุดที่ 2 : '))
                    lc3 = int(input('จุดที่ 3 : '))
                    lc4 = int(input('จุดที่ 4 : '))

                    arr=[lc1,lc2,lc3,lc4]
                    newarr = sorted(arr)       
                    
                    print('เส้นทางที่สั้นที่สุด : ',
                    newarr)            #ไม่มีทางผ่าน   
                    #nx.shortest_path(g, source=newarr[0], target=newarr[1] and newarr[2] and newarr[3] )) #มีทางผ่าน
                    print('ระยะที่สั้นที่สุด : ',
                    nx.shortest_path_length(g, source=lc1, target=lc2 and lc3 and lc4 , weight='weight'),'km.')               
                    plt.show()
                    
          if lc =="5":
                    min =0
                    max =0
                    mid = 0
                    mid1 =0
                    mid2 =0
                    arr=[]
                    newarr=[]

                    lc1 = int(input('จุดที่ 1 : '))
                    lc2 = int(input('จุดที่ 2 : '))
                    lc3 = int(input('จุดที่ 3 : '))
                    lc4 = int(input('จุดที่ 4 : '))
                    lc5 = int(input('จุดที่ 5 : '))
                    arr=[lc1,lc2,lc3,lc4,lc5]
                    newarr = sorted(arr)
                     
                   

                    print('เส้นทางที่สั้นที่สุด : ',
                    newarr)      
                    #nx.shortest_path(g, source=newarr[0], target=newarr[1] and newarr[2] and newarr[3] and newarr[4] ))

                    print('ระยะที่สั้นที่สุด : ',
                    nx.shortest_path_length(g, source=lc1, target=lc2 and lc3 and lc4 and lc5, weight='weight'),'km.')
                    plt.show()
                
            
    if n == "3":
        
        kilo = int(input("ป้อนระยะทาง(กิโลเมตร) : "))
        price = 0
 
        if kilo > 80:
            x_kilo = (kilo - 80)
            price += x_kilo * 10.50
            kilo -= x_kilo
 
        if kilo > 60:
            x_kilo = (kilo - 60)
            price += x_kilo * 9
            kilo -= x_kilo
 
        if kilo > 40:
            x_kilo = (kilo - 40)
            price += x_kilo * 8
            kilo -= x_kilo
 
        if kilo > 20:
            x_kilo = (kilo - 20)
            price += x_kilo * 7.50
            kilo -= x_kilo
 
        if kilo > 10:
            x_kilo = (kilo - 10)
            price += x_kilo * 6.50
            kilo -= x_kilo
 
        if kilo > 1:
            x_kilo = (kilo - 1)
            price += x_kilo * 5.50
            kilo -= x_kilo
 
        if kilo == 1:
            price += 35
 
        if round(price) % 2 == 0:
            price += 1
 
        print("\nค่าแท็กซี่ทั้งหมด %.0f บาท"% price);
        plt.show()


    if n == "4":
        break
# Out:
# --------------------------------------------------
# |                      MENU                      |
# --------------------------------------------------
# | 1.หาเส้นทางสั้นสุดจาก A -> B                       |
# | 2.กำหนดได้ว่า ไปเที่ยว 2-5 ที่ แนะนำเส้นทางที่สั้นสุด      |
# |  สำหรับเดินทางเที่ยว 5 ที่ คือเส้นทางไหน               |
# | 3.คิดค่าแท็กซี่                                     |
# | 4.ออกจากเมนู                                    |
# --------------------------------------------------
# เส้นทางที่สั้นที่สุด :  [2, 4, 19, 20]
# ระยะที่สั้นที่สุด :  0 km.
# --------------------------------------------------
# |                      MENU                      |
# --------------------------------------------------
# | 1.หาเส้นทางสั้นสุดจาก A -> B                       |
# | 2.กำหนดได้ว่า ไปเที่ยว 2-5 ที่ แนะนำเส้นทางที่สั้นสุด      |
# |  สำหรับเดินทางเที่ยว 5 ที่ คือเส้นทางไหน               |
# | 3.คิดค่าแท็กซี่                                     |
# ...
