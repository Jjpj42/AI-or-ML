# %%
pip install dnspython
# Out:
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.1.0)

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (3.12.0)

# %%
import datetime # Imports datetime library
import pymongo
from pymongo import MongoClient
client = pymongo.MongoClient("mongodb://jaturaphat:0927477441@cluster0-shard-00-00.o5jd5.mongodb.net:27017,cluster0-shard-00-01.o5jd5.mongodb.net:27017,cluster0-shard-00-02.o5jd5.mongodb.net:27017/Cluster0?ssl=true&replicaSet=atlas-iezq19-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test
client.stats
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.o5jd5.mongodb.net:27017', 'cluster0-shard-00-02.o5jd5.mongodb.net:27017', 'cluster0-shard-00-01.o5jd5.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='atlas-iezq19-shard-0', authsource='admin', retrywrites=True, w='majority'), 'stats')

# %%
print(client.list_database_names())
db = client.get_database('student_db')
records = db.student_records
# Out:
# ['student_db', 'admin', 'local']

# %%
records.count_documents({ })
# Out:
# 2

# %%
new_student = {
  'name': 'naphat',
  'roll_no': 321,
  'branch' : 'it'
}

records.insert_one(new_student)

# %%
new_students = [
  {
  'name': 'anutin',
  'roll_no': 325,
  'branch' : 'buriram'
  },
  {
  'name' : 'prayuth',
  'roll_no': 30,
  'branch' : 'bangkok'
  }
]

records.insert(new_students)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# [ObjectId('612c8fb35f62a98dd1669a64'), ObjectId('612c8fb35f62a98dd1669a65')]

# %%
student_updates = {
  'name' : 'prawit'
}

records.update_one({'roll_no': 30},{'$set': student_updates})

# %%
records.delete_one({'roll_no' : 30})
