# %%
pip install dnspython
# Out:
# Collecting dnspython
#   Downloading dnspython-2.1.0-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 5.0 MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-2.1.0

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)

# %%
pip install songline
# Out:
# Collecting songline
#   Downloading songline-0.0.1.tar.gz (2.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from songline) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->songline) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->songline) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->songline) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->songline) (3.0.4)
# Building wheels for collected packages: songline
#   Building wheel for songline (setup.py) ... done
#   Created wheel for songline: filename=songline-0.0.1-py3-none-any.whl size=2429 sha256=5d6ac0143f37d120cf3fbc471d65cf5f097b79afad7c3bbfaee826b50746d329
#   Stored in directory: /root/.cache/pip/wheels/eb/94/d6/e64187abb8f60812b10b6cd40d34ba9aa13367656fc1c023d7
# Successfully built songline
# Installing collected packages: songline
# Successfully installed songline-0.0.1

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (3.12.0)

# %%
import pandas as pd
import bs4
import requests
import openpyxl
import songline
import datetime # Imports datetime library
import pymongo
from pymongo import MongoClient
client = pymongo.MongoClient("mongodb://jaturaphat:0927477441@cluster0-shard-00-00.o5jd5.mongodb.net:27017,cluster0-shard-00-01.o5jd5.mongodb.net:27017,cluster0-shard-00-02.o5jd5.mongodb.net:27017/Cluster0?ssl=true&replicaSet=atlas-iezq19-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test
client.stats
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.o5jd5.mongodb.net:27017', 'cluster0-shard-00-02.o5jd5.mongodb.net:27017', 'cluster0-shard-00-01.o5jd5.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='atlas-iezq19-shard-0', authsource='admin', retrywrites=True, w='majority'), 'stats')

# %%
db = client.get_database('student_db')
records = db.HW_bd
def mk(page):
 
  name_list = []
  price_list = []
  name = []
  pprice = []
  count = 0
  while page <= 5:
    data = requests.get('https://www.mk1642.com/th/Product/Promotion.aspx')
    soup = bs4.BeautifulSoup(data.text)
    for c in soup.find_all('div',{'class':'card-template cmn-t-translate-bshadow product-card-padding'}):
      name_list.append(c.find('div',{'class':'col-6 topic-divide text-left'}).find('a').text)

      try:
        p = c.find('div',{'class':'txt-price'}).text
        price = p
      except :
        print('')
      new_product={
          'product':name_list[count],
          'price':price
      }
      count=count+1
      records.insert(new_product)
      print(count)

      if p == 'call':
        price_list.append(price)
      else:
        price_list.append(str(price))
      
      name.append('รายการ : {}'.format(name_list))
      pprice.append('ราคา : {}'.format(price))
    print('Complete page number: ',page)
    page += 1
    table = pd.DataFrame([name_list,price_list]).transpose()
    table.columns = ['name','price']
    table.set_index('name')
    table.to_excel('web_scraping.xlsx',engine='openpyxl')
    return (name[0])

# %%
print(mk(1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# Complete page number:  1
# รายการ : ['ชุดบอกรักแม่ ชุด1']

# %%
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.o5jd5.mongodb.net:27017', 'cluster0-shard-00-02.o5jd5.mongodb.net:27017', 'cluster0-shard-00-01.o5jd5.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='atlas-iezq19-shard-0', authsource='admin', retrywrites=True, w='majority'), 'stats')
