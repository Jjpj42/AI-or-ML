# %%
pip install urllib3

# %%
import urllib
url = 'https://opend.data.go.th/get-ckan/datastore_search?resource_id=225ff892-3874-4072-9787-a2c30128e3f7&limit=5'  
print(url)
#fileobj = urllib.urlopen(url)
#print (fileobj.read())
# Out:
# https://opend.data.go.th/get-ckan/datastore_search?resource_id=225ff892-3874-4072-9787-a2c30128e3f7&limit=5
